# %% [markdown]
# Here I'm going to organize the data.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = pd.read_excel('data.xlsx')

data.head()

plt.scatter(data["time"],data["Hp"])
plt.xlabel("time (min)")
plt.ylabel("Hemoglobin concentration (mg/dL)")
# Out:
# Text(0, 0.5, 'Hemoglobin concentration (mg/dL)')
